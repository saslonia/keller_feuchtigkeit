# %% [markdown]
# # Feuchtigkeitsuntersuchung Keller am 29.03.2024

# %% [markdown]
# ### Verwendete Geräte
#
# - **Messung Wandfeuchte:** [Feuchtigkeitsmessgerät PCE-PMI 2](https://www.pce-instruments.com/deutsch/messtechnik/messgeraete-fuer-alle-parameter/feuchtigkeitsmessgeraet-feuchtigkeitsmesser-pce-instruments-feuchtigkeitsmessgeraet-pce-pmi-2-det_3650544.htm)
# mit der Kennlinie 10 für eine Materialdichte von 600 kg/m³ (Porenbeton)
# - **Messung Wandtemperatur:** [Bosch Infrarotthermometer UniversalTemp](https://www.amazon.de/dp/B0CFVZQFZ5?ref=ppx_yo2ov_dt_b_product_details&th=1)
# - **Lufttemperatur und -feuchtigkeit:** [ThermoPro TP50 digitales Thermo-Hygrometer](https://www.amazon.de/dp/B01H1R0K68?psc=1&ref=ppx_yo2ov_dt_b_product_details)
# - **Schimmeltest:** [airself quantitativer Schimmelpilz Schnelltest](https://www.amazon.de/dp/B06Y12S6KD?ref=ppx_yo2ov_dt_b_product_details&th=1)

# %% [markdown]
# ### Import von Code und Daten

# %%
import pandas as pd
from helper_functions import create_plots
df = pd.read_csv("data/20240329_measurement.csv")

# %% [markdown]
# ### Über die Interpretation der Messwerte
#
# #### Feuchtigkeit der Wände
#
# Laut [dieser Quelle](https://www.ausbaupraxis.de/feucht-oder-froehlich-die-feuchtemessung-17112021) sind die Messwerte wie folgt zu bewerten. In den folgenden Diagrammen werden die Kategorien auch farblich entsprechend gekennzeichnet.
#
# - bis 40 Skalenanteile: trockener Baustoff --> grün
# - 40 – 80 Skalenanteile: mäßig feucht (Material-Ausgleichsfeuchte) --> gelb
# - 80 – 100 Skalenanteile: erhöhte Baustofffeuchte --> orange
# - 100 – 150 Skalenanteile: durchfeuchtetes Bauteil --> rot (ab 150 richtung schwarz)
#
# > ❗**Achtung:** Die Messwerte können durch andere Materialien in der unmittelbaren Nähe der Messung stark beeinflusst werden.
# > Diese Materialien erzeugen einen höheren Messwert:
# > - Metall
# > - Salz
# > - Beton (Boden und Decke des Raumes)
#
# #### Diagramme
#
# - Alle Diagramme haben dieselbe Farbskala, damit sie miteinander vergleichbar sind.
# - In den Diagrammen sind kleine graue Kreuze zu finden. Diese markieren die tatsächlichen Messpunkte.

# %% [markdown]
# ## Fahrradkeller
#
# - **Startzeit der Messung:** 14:10 Uhr
# - **Relative Luftfeuchtigkeit:** 50%
# - **Lufttemperatur:** 20°C
# - **Subjektiver Eindruck Luft/Raumgefühl:** leicht muffig

# %% [markdown]
# ### Südwand (Fahrradkeller)
#
# #### Auffälligkeiten
#
# **Unterer rechter Teil:** abgeplatzte Farbe/Putz (Hinweis auf Feuchtigkeit), dies zeigt sich auch in den Messergebnissen. Eventuell eine Altlast aus der Bauphase und keine undichte Stelle.
#
# <img src="images/fahrradkeller_suedwand_rechts.jpg" width="67%" />
# <img src="images/fahrradkeller_ecke_suedwand_westwand.jpg" width="30%" />
#
# **Rand links:** etwas feuchter, möglicherweise wegen kaltem Treppenhaus nebenan
#
# **Rand unten:** etwas feuchter, hinter Styroporstreifen, evtl. Messwerte durch Beton am Boden beeinflusst
#
# Ansonsten vorrangig trocken.

# %%
create_plots(df, "Fahrradkeller", "Südwand")

# %% [markdown]
# ### Westwand (Fahrradkeller)
#
# #### Auffälligkeiten
#
# **Unter Hausabfluss:** sehr feucht, schmierig, evtl. Schimmel. Feuchtigkeit "strahlt rundherum aus". Sehr wahrscheinlich leicht undichte Stelle.  -> Prüfen ob Abdichtung auch von innen möglcih
#
# ❗Bild fehlt noch
#
# **Ecke unten rechts:** etwas erhöhte Feuchtigkeit, wahrscheinlich ähnlicher Grund wie Norwand (folgt als nächstes)
#
# Ansonsten

# %%
create_plots(df, "Fahrradkeller", "Westwand")

# %% [markdown]
# ### Nordwand (Fahrradkeller, Innenwand zum Technikraum)
#
# Keine detaillierte Messung, da Innenwand
#
# #### Auffälligkeiten
#
# Unten am Boden auf ca. 2,5 m Länge abgeplatzte Farbe/Putz, abnehmend von Außenwand zum Innenraum, gemessene Feuchtigkeit zwischen 60 und 90 digits (mäßig feucht bis erhöhte Feuchtigkeit). Das kann evtl. eine Altlast aus der Bauphase sein (rechtes Bild).
#
# <img src="images\fahrradkeller_nordwand.jpg" width="74%" />
# <img src="images\fahrradkeller_bauphase.jpg" width="23%" />

# %% [markdown]
# ## Technikraum
#
# - **Startzeit der Messung:** 17:00 Uhr
# - **Relative Luftfeuchtigkeit:** 42%
# - **Lufttemperatur:** 29°C
# - **Subjektiver Eindruck Luft/Raumgefühl:** sehr sehr warm

# %% [markdown]
# ### Südwand (Technikraum, Innenwand zum Fahrradkeller)
#
# Keine detaillierte Messung, da Innenwand
#
# #### Auffälligkeiten
#
# Unten am Boden auf ca. 1 m Länge abgeplatzte Farbe/Putz, abnehmend von Außenwand zum Innenraum, gemessene Feuchtigkeit zwischen 60 und 80 digits (mäßig feucht bis leicht erhöhte Feuchtigkeit). Das kann evtl. eine Altlast aus der Bauphase sein (rechtes Bild).
#
# <img src="images\technikraum_suedwand.jpg" width="65%" />
# <img src="images\technikraum_bauphase.jpg" width="31%" />

# %% [markdown]
# ### Westwand (Technikraum)
#
# #### Auffälligkeiten
#
# **Hausanschluss Kaltwasser:** leicht erhöhte Feuchtigkeit um die Kaltwasserzuleitung. An der kalten Leitung sammelt sich Kondenswasser, das auch herunter tropft. Würde ich erstmal nicht als kritisch bewerten.
#
# <img src="images\technikraum_westwand.jpg" width="48%" />
# <img src="images\technikraum_kalte_wasserzuleitung.jpg" width="48%" />
#
# Ansonsten trocken.

# %%
create_plots(df, "Technikraum", "Westwand")

# %% [markdown]
# ## Keller 5
#
# - **Startzeit der Messung:** 17:50 Uhr
# - **Relative Luftfeuchtigkeit:** 65%
# - **Lufttemperatur:** 21,2°C
# - **Subjektiver Eindruck Luft/Raumgefühl:** muffig

# %% [markdown]
# ### Südwand (Keller 5, Innenwand zum Technikraum)
#
# Keine detaillierte Messung, da Innenwand
#
# #### Auffälligkeiten
#
# **Ecke unten rechts:** Aussalzung, Messwerte zwischen 80 und 100, ca. 30cm breit, 25cm hoch, Feuchtigkeit nimmt vom Zentrum der Aussalzung aus ab, an der Stelle stand ein Karton, hat möglicherweise Wasser gezogen und bei der Wand gehalten.
#
# <img src="images\keller5_suedwand.jpg" width="60%" />
# <img src="images\keller5_ecke_suedwest.jpg" width="38%" />

# %% [markdown]
# ### Westwand (Keller 5)
#
# #### Auffälligkeiten
#
# Allgemein etwas feucht. Unten rechts deutlich fechter, evtl durch einen Karton, der dort stand.
#
# Außenwand wahrscheinlich nicht undicht.

# %%
create_plots(df, "Keller 5", "Westwand")

# %% [markdown]
# ## Keller 1
#
# - **Startzeit der Messung:** 18:30 Uhr
# - **Relative Luftfeuchtigkeit:** 69%
# - **Lufttemperatur:** 19,9°C
# - **Subjektiver Eindruck Luft/Raumgefühl:** muffig
#
# Diese Tür dieses Raumes steht regelmäßig offen.

# %% [markdown]
# ### Westwand (Keller 1)
#
# #### Auffälligkeiten
#
# **Ecke unten rechts:** Aussazung mit start erhöhten Feuchtigkeitsmesswerten (Achtung: Salz beeinflusst die Messwerte). Ob hier eine undichte Stelle ist, muss weiter untersucht werden (Salz entfernen (z.B. durch Opferputz), Trocknungsgeräte aufstellen und beobachten, ob Wasser nachströmt).
#
# <img src="images\keller1_aussalzung.jpg" width="48%" />
# <img src="images\keller1_aussalzung2.jpg" width="48%" />
#
# Ansonsten trocken bis ein wenig feucht.

# %%
create_plots(df, "Keller 1", "Westwand")

# %% [markdown]
# ### Nordwand (Keller 1)
#
# #### Auffälligkeiten
#
# **Ecke unten links:** Aussalzung, wie an Westwand
# **Ecke unten rechts:** Feuchte Stelle, dort stand ein Stapel Fliesen in Pappverpackung sehr nah an der Wand. Dort ist auf eine verfärbte Stelle entstanden (Schimmel?)
#
# <img src="images\keller1_nordwand_rechte_ecke.jpg" width="50%" />
#
# Allgemein war die Wand relativ stark mit Gegenständen zugestellt und hat insgesamt eine erhöhte Feuchtigkeit.

# %%
create_plots(df, "Keller 1", "Nordwand")

# %% [markdown]
# ## Keller 2
#
# - **Startzeit der Messung:** 19:30 Uhr
# - **Relative Luftfeuchtigkeit:** 72%
# - **Lufttemperatur:** 19,7°C
# - **Subjektiver Eindruck Luft/Raumgefühl:** weder wirklich muffig noch frisch
#
# Diese Tür dieses Raumes steht regelmäßig offen und es stehen nur 2 Fahrräder darin (keine Wand zugestellt)

# %% [markdown]
# ### Nordwand (Keller 2)
#
# #### Auffälligkeiten
#
# Bei der Übergabe im Sommer 2023 war die Ecke unten rechts noch sehr feucht (130 digits vom Gutachter gemessen) und die Ecke hat geschimmelt. Das hat sich deutlich gebessert.
#
# Trotzdem allgemein eher feucht und noch nicht trocken.

# %%
create_plots(df, "Keller 2", "Nordwand")

# %% [markdown]
# ## Keller 3

# %%
create_plots(df, "Keller 3", "Nordwand")

# %% [markdown]
# ## Keller 4

# %% [markdown]
# ### Norwand

# %%
create_plots(df, "Keller 4", "Nordwand")

# %% [markdown]
# ## Ostwand

# %%
# nur 1 Streifen gemessen

# %% [markdown]
# ## Keller 8

# %% [markdown]
# ### Ostwand

# %%
create_plots(df, "Keller 8", "Ostwand")

# %% [markdown]
# ## Keller 9

# %% [markdown]
# ### Ostwand

# %%
create_plots(df, "Keller 9", "Ostwand")
